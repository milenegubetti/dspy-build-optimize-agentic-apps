# %% [markdown]
# # MCP

# %% [markdown]
# ## Using MCP with DSPy

# %% [markdown]
# 1. [HTTP Server (Remote)](https://dspy.ai/learn/programming/mcp/#1-http-server-remote)
#
# 2. [Stdio Server (Local Process)](https://dspy.ai/learn/programming/mcp/#2-stdio-server-local-process)
