# %% [markdown]
# # Install DSPy and set up your LM

# %% [markdown]
# ## Local LMs on your laptop

# %%
import dspy
lm = dspy.LM("ollama_chat/llama3.2:1b", api_base="http://localhost:11434", api_key="")
dspy.configure(lm=lm)
